# %% [markdown]
# # ML Week 1

# %% [markdown]
# ## Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Data
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([40, 50, 60, 65, 80])

# Train model
model = LinearRegression()
model.fit(X, y)

# Create regression line
X_line = np.linspace(1, 5, 100).reshape(-1, 1)
y_line = model.predict(X_line)

# Plot
plt.scatter(X, y, label="Data Points")
plt.plot(X_line, y_line, label="Regression Line")
plt.xlabel("Hours Studied")
plt.ylabel("Marks")
plt.title("Study Hours vs Marks with Regression Line")
plt.legend()
plt.show()

# Prediction
prediction = model.predict([[20]])
print("Predicted marks for  hours:", prediction[0])
# Out:
# Predicted marks for  hours: 220.50000000000003
